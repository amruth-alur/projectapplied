# %%
import numpy as np
import pandas as pd

# %%
df_max_temp = pd.read_csv('Maximum-Temperature.csv')

# %%
df_min_temp = pd.read_csv('Minimum-Temperature.csv')

# %%
df_max_temp.head()
# Out:
#    Dist Code  Year  State Code State Name  Dist Name  \
# 0        165  2000           9     Punjab  Gurdaspur
# 1        165  2001           9     Punjab  Gurdaspur
# 2        165  2002           9     Punjab  Gurdaspur
# 3        165  2003           9     Punjab  Gurdaspur
# 4        165  2004           9     Punjab  Gurdaspur
#
#    JANUARY MAXIMUM (Centigrate)  FEBRUARY MAXIMUM (Centigrate)  \
# 0                         17.78                          20.25
# 1                         17.76                          23.28
# 2                         18.06                          21.61
# 3                         17.94                          21.22
# 4                         17.49                          23.87
#
#    MARCH MAXIMUM (Centigrate)  APRIL MAXIMUM (Centigrate)  \
# 0                       26.34                       34.54
# 1                       28.00                       32.74
# 2                       28.49                       33.92
# ...

# %%
df_max_temp.drop(['State Code','State Name'],axis=1, inplace=True)

# %%
df_max_temp.head()
# Out:
#    Dist Code  Year  Dist Name  JANUARY MAXIMUM (Centigrate)  \
# 0        165  2000  Gurdaspur                         17.78
# 1        165  2001  Gurdaspur                         17.76
# 2        165  2002  Gurdaspur                         18.06
# 3        165  2003  Gurdaspur                         17.94
# 4        165  2004  Gurdaspur                         17.49
#
#    FEBRUARY MAXIMUM (Centigrate)  MARCH MAXIMUM (Centigrate)  \
# 0                          20.25                       26.34
# 1                          23.28                       28.00
# 2                          21.61                       28.49
# 3                          21.22                       26.15
# 4                          23.87                       31.02
#
#    APRIL MAXIMUM (Centigrate)  MAY MAXIMUM (Centigrate)  \
# 0                       34.54                     40.42
# 1                       32.74                     39.53
# 2                       33.92                     39.90
# ...

# %%
df_max_temp['max_avg'] = df_max_temp.iloc[:,3:-1].mean(axis=1)

# %%
df_max_temp.head()
# Out:
#    Dist Code  Year  Dist Name  JANUARY MAXIMUM (Centigrate)  \
# 0        165  2000  Gurdaspur                         17.78
# 1        165  2001  Gurdaspur                         17.76
# 2        165  2002  Gurdaspur                         18.06
# 3        165  2003  Gurdaspur                         17.94
# 4        165  2004  Gurdaspur                         17.49
#
#    FEBRUARY MAXIMUM (Centigrate)  MARCH MAXIMUM (Centigrate)  \
# 0                          20.25                       26.34
# 1                          23.28                       28.00
# 2                          21.61                       28.49
# 3                          21.22                       26.15
# 4                          23.87                       31.02
#
#    APRIL MAXIMUM (Centigrate)  MAY MAXIMUM (Centigrate)  \
# 0                       34.54                     40.42
# 1                       32.74                     39.53
# 2                       33.92                     39.90
# ...

# %%
df_max_temp.columns
# Out:
# Index(['Dist Code', 'Year', 'Dist Name', 'JANUARY MAXIMUM (Centigrate)',
#        'FEBRUARY MAXIMUM (Centigrate)', 'MARCH MAXIMUM (Centigrate)',
#        'APRIL MAXIMUM (Centigrate)', 'MAY MAXIMUM (Centigrate)',
#        'JUNE MAXIMUM (Centigrate)', 'JULY MAXIMUM (Centigrate)',
#        'AUGUST MAXIMUM (Centigrate)', 'SEPTEMBER MAXIMUM (Centigrate)',
#        'OCTOBER MAXIMUM (Centigrate)', 'NOVEMBER MAXIMUM (Centigrate)',
#        'DECEMBER MAXIMUM (Centigrate)', 'max_avg'],
#       dtype='object')

# %%
df_max_temp.drop(['JANUARY MAXIMUM (Centigrate)',
       'FEBRUARY MAXIMUM (Centigrate)', 'MARCH MAXIMUM (Centigrate)',
       'APRIL MAXIMUM (Centigrate)', 'MAY MAXIMUM (Centigrate)',
       'JUNE MAXIMUM (Centigrate)', 'JULY MAXIMUM (Centigrate)',
       'AUGUST MAXIMUM (Centigrate)', 'SEPTEMBER MAXIMUM (Centigrate)',
       'OCTOBER MAXIMUM (Centigrate)', 'NOVEMBER MAXIMUM (Centigrate)',
       'DECEMBER MAXIMUM (Centigrate)'], axis=1, inplace=True)

# %%
df_max_temp.head()
# Out:
#    Dist Code  Year  Dist Name    max_avg
# 0        165  2000  Gurdaspur  30.214545
# 1        165  2001  Gurdaspur  30.346364
# 2        165  2002  Gurdaspur  30.286364
# 3        165  2003  Gurdaspur  29.495455
# 4        165  2004  Gurdaspur  30.422727

# %%
df_max_temp.to_csv('modfied-max-temp.csv')

# %%
df_min_temp.drop(['State Code','State Name'],axis=1, inplace=True)

# %%
df_min_temp.head()
# Out:
#    Dist Code  Year  Dist Name  JANUARY MINIMUM (Centigrate)  \
# 0        165  2000  Gurdaspur                          6.51
# 1        165  2001  Gurdaspur                          5.77
# 2        165  2002  Gurdaspur                          6.17
# 3        165  2003  Gurdaspur                          5.54
# 4        165  2004  Gurdaspur                          7.13
#
#    FEBRUARY MINIMUM (Centigrate)  MARCH MINIMUM (Centigrate)  \
# 0                           7.39                       12.97
# 1                           9.84                       14.23
# 2                           8.57                       14.08
# 3                           9.09                       13.63
# 4                           8.88                       16.30
#
#    APRIL MINIMUM (Centigrate)  MAY MINIMUM (Centigrate)  \
# 0                       19.55                     26.07
# 1                       18.64                     25.10
# 2                       19.74                     24.41
# ...

# %%
df_min_temp['min_avg'] = df_min_temp.iloc[:,3:-1].mean(axis=1)

# %%
df_min_temp.head()
# Out:
#    Dist Code  Year  Dist Name  JANUARY MINIMUM (Centigrate)  \
# 0        165  2000  Gurdaspur                          6.51
# 1        165  2001  Gurdaspur                          5.77
# 2        165  2002  Gurdaspur                          6.17
# 3        165  2003  Gurdaspur                          5.54
# 4        165  2004  Gurdaspur                          7.13
#
#    FEBRUARY MINIMUM (Centigrate)  MARCH MINIMUM (Centigrate)  \
# 0                           7.39                       12.97
# 1                           9.84                       14.23
# 2                           8.57                       14.08
# 3                           9.09                       13.63
# 4                           8.88                       16.30
#
#    APRIL MINIMUM (Centigrate)  MAY MINIMUM (Centigrate)  \
# 0                       19.55                     26.07
# 1                       18.64                     25.10
# 2                       19.74                     24.41
# ...

# %%
df_min_temp.columns
# Out:
# Index(['Dist Code', 'Year', 'Dist Name', 'JANUARY MINIMUM (Centigrate)',
#        'FEBRUARY MINIMUM (Centigrate)', 'MARCH MINIMUM (Centigrate)',
#        'APRIL MINIMUM (Centigrate)', 'MAY MINIMUM (Centigrate)',
#        'JUNE MINIMUM (Centigrate)', 'JULY MINIMUM (Centigrate)',
#        'AUGUST MINIMUM (Centigrate)', 'SEPTEMBER MINIMUM (Centigrate)',
#        'OCTOBER MINIMUM (Centigrate)', 'NOVEMBER MINIMUM (Centigrate)',
#        'DECEMBER MINIMUM (Centigrate)', 'min_avg'],
#       dtype='object')

# %%
df_min_temp.drop(['JANUARY MINIMUM (Centigrate)',
       'FEBRUARY MINIMUM (Centigrate)', 'MARCH MINIMUM (Centigrate)',
       'APRIL MINIMUM (Centigrate)', 'MAY MINIMUM (Centigrate)',
       'JUNE MINIMUM (Centigrate)', 'JULY MINIMUM (Centigrate)',
       'AUGUST MINIMUM (Centigrate)', 'SEPTEMBER MINIMUM (Centigrate)',
       'OCTOBER MINIMUM (Centigrate)', 'NOVEMBER MINIMUM (Centigrate)',
       'DECEMBER MINIMUM (Centigrate)'] ,axis=1, inplace=True)

# %%
df_max_temp.columns
# Out:
# Index(['Dist Code', 'Year', 'Dist Name', 'max_avg'], dtype='object')

# %%
df_min_temp.head()
# Out:
#    Dist Code  Year  Dist Name    min_avg
# 0        165  2000  Gurdaspur  18.368182
# 1        165  2001  Gurdaspur  18.427273
# 2        165  2002  Gurdaspur  18.379091
# 3        165  2003  Gurdaspur  17.845455
# 4        165  2004  Gurdaspur  18.132727

# %%
new_df = pd.DataFrame({'Year':df_max_temp['Year'],'Dist Name':df_max_temp['Dist Name'], 'max_avg':df_max_temp['max_avg'],'min_avg':df_min_temp['min_avg']})

# %%
new_df.head()
# Out:
#    Year  Dist Name    max_avg    min_avg
# 0  2000  Gurdaspur  30.214545  18.368182
# 1  2001  Gurdaspur  30.346364  18.427273
# 2  2002  Gurdaspur  30.286364  18.379091
# 3  2003  Gurdaspur  29.495455  17.845455
# 4  2004  Gurdaspur  30.422727  18.132727

# %%
new_df.describe()
# Out:
#               Year     max_avg     min_avg
# count   176.000000  176.000000  176.000000
# mean   2007.500000   31.388388   18.459912
# std       4.622924    0.867897    0.357474
# min    2000.000000   29.271818   17.671818
# 25%    2003.750000   30.854318   18.228409
# 50%    2007.500000   31.401818   18.437727
# 75%    2011.250000   31.995000   18.650909
# max    2015.000000   33.559091   19.355455

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 176 entries, 0 to 175
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Year       176 non-null    int64
#  1   Dist Name  176 non-null    object
#  2   max_avg    176 non-null    float64
#  3   min_avg    176 non-null    float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 5.6+ KB

# %%
year2000 = new_df.loc[new_df['Year'] == 2000]
year2001 = new_df.loc[new_df['Year'] == 2001]
year2002 = new_df.loc[new_df['Year'] == 2002]
year2003 = new_df.loc[new_df['Year'] == 2003]
year2004 = new_df.loc[new_df['Year'] == 2004]
year2005 = new_df.loc[new_df['Year'] == 2005]
year2006 = new_df.loc[new_df['Year'] == 2006]
year2007 = new_df.loc[new_df['Year'] == 2007]
year2008 = new_df.loc[new_df['Year'] == 2008]
year2009 = new_df.loc[new_df['Year'] == 2009]
year2010 = new_df.loc[new_df['Year'] == 2010]
year2011 = new_df.loc[new_df['Year'] == 2011]
year2012 = new_df.loc[new_df['Year'] == 2012]
year2013 = new_df.loc[new_df['Year'] == 2013]
year2014 = new_df.loc[new_df['Year'] == 2014]
year2015 = new_df.loc[new_df['Year'] == 2015]

# %%
max_temp_2000 = year2000['max_avg'].mean(axis=0)
min_temp_2000 = year2000['min_avg'].mean(axis=0)
avg_temp_2000 = np.mean([max_temp_2000, min_temp_2000])
print(avg_temp_2000)
# Out:
# 24.982851239669422

# %%
max_temp_2001 = year2001['max_avg'].mean(axis=0)
min_temp_2001 = year2001['min_avg'].mean(axis=0)
avg_temp_2001 = np.mean([max_temp_2001, min_temp_2001])
print(avg_temp_2001)
# Out:
# 25.005619834710743

# %%
max_temp_2002 = year2002['max_avg'].mean(axis=0)
min_temp_2002 = year2002['min_avg'].mean(axis=0)
avg_temp_2002 = np.mean([max_temp_2002, min_temp_2002])
print(avg_temp_2002)
# Out:
# 25.211735537190087

# %%
max_temp_2003 = year2003['max_avg'].mean(axis=0)
min_temp_2003 = year2003['min_avg'].mean(axis=0)
avg_temp_2003 = np.mean([max_temp_2003, min_temp_2003])
print(avg_temp_2003)
# Out:
# 24.42123966942149

# %%
max_temp_2004 = year2004['max_avg'].mean(axis=0)
min_temp_2004 = year2004['min_avg'].mean(axis=0)
avg_temp_2004 = np.mean([max_temp_2004, min_temp_2004])
print(avg_temp_2004)
# Out:
# 25.097479338842973

# %%
max_temp_2005 = year2005['max_avg'].mean(axis=0)
min_temp_2005 = year2005['min_avg'].mean(axis=0)
avg_temp_2005 = np.mean([max_temp_2005, min_temp_2005])
print(avg_temp_2005)
# Out:
# 24.49202479338843

# %%
max_temp_2006 = year2006['max_avg'].mean(axis=0)
min_temp_2006 = year2006['min_avg'].mean(axis=0)
avg_temp_2006 = np.mean([max_temp_2006, min_temp_2006])
print(avg_temp_2006)
# Out:
# 25.3498347107438

# %%
max_temp_2007 = year2007['max_avg'].mean(axis=0)
min_temp_2007 = year2007['min_avg'].mean(axis=0)
avg_temp_2007 = np.mean([max_temp_2007, min_temp_2007])
print(avg_temp_2007)
# Out:
# 25.05004132231405

# %%
max_temp_2008 = year2008['max_avg'].mean(axis=0)
min_temp_2008 = year2008['min_avg'].mean(axis=0)
avg_temp_2008 = np.mean([max_temp_2008, min_temp_2008])
print(avg_temp_2008)
# Out:
# 24.63012396694215

# %%
max_temp_2009 = year2009['max_avg'].mean(axis=0)
min_temp_2009 = year2009['min_avg'].mean(axis=0)
avg_temp_2009 = np.mean([max_temp_2009, min_temp_2009])
print(avg_temp_2009)
# Out:
# 25.29876033057851

# %%
max_temp_2010 = year2010['max_avg'].mean(axis=0)
min_temp_2010 = year2010['min_avg'].mean(axis=0)
avg_temp_2010 = np.mean([max_temp_2010, min_temp_2010])
print(avg_temp_2010)
# Out:
# 25.61177685950413

# %%
max_temp_2011 = year2011['max_avg'].mean(axis=0)
min_temp_2011 = year2011['min_avg'].mean(axis=0)
avg_temp_2011 = np.mean([max_temp_2011, min_temp_2011])
print(avg_temp_2011)
# Out:
# 24.936983471074385

# %%
max_temp_2012 = year2012['max_avg'].mean(axis=0)
min_temp_2012 = year2012['min_avg'].mean(axis=0)
avg_temp_2012 = np.mean([max_temp_2012, min_temp_2012])
print(avg_temp_2012)
# Out:
# 24.649173553719006

# %%
max_temp_2013 = year2013['max_avg'].mean(axis=0)
min_temp_2013 = year2013['min_avg'].mean(axis=0)
avg_temp_2013 = np.mean([max_temp_2013, min_temp_2013])
print(avg_temp_2013)
# Out:
# 24.79801652892562

# %%
max_temp_2014 = year2014['max_avg'].mean(axis=0)
min_temp_2014 = year2014['min_avg'].mean(axis=0)
avg_temp_2014 = np.mean([max_temp_2014, min_temp_2014])
print(avg_temp_2014)
# Out:
# 24.629173553719006

# %%
max_temp_2015 = year2015['max_avg'].mean(axis=0)
min_temp_2015 = year2015['min_avg'].mean(axis=0)
avg_temp_2015 = np.mean([max_temp_2015, min_temp_2015])
print(avg_temp_2015)
# Out:
# 24.62157024793389
